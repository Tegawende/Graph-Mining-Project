# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
def load_graph_from_csv():
    df = pd.read_csv("datasets/primaryschool.csv", delim_whitespace=True, header=None, names=['Time', 'Person1','Person2','Class1', 'Class2'])
    return nx.from_pandas_edgelist(df, 'Person1', 'Person2', edge_attr=['Time', 'Class1', 'Class2'])
#     Graphtype = nx.Graph()
#     return nx.from_pandas_edgelist(df, 'Person1', 'Person2', edge_attr=['Time', 'Class1', 'Class2'], create_using=Graphtype)


    
def draw_graph (G, colors = None, pos = "None"):
    plt.figure (figsize=(15,15))
#     if not pos:
    pos = nx.spring_layout(G)
#     nx.draw(G, pos)
    nx.draw_networkx_nodes(G, pos, node_color=colors, cmap=plt.cm.YlOrRd)
    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos) 
    plt.show()

print('matplotlib: {}'.format(matplotlib.__version__))
G = load_graph_from_csv()

# basic information
print(nx.info(G))

draw_graph(G)
# pos = nx.random_layout(G)
# nx.draw(G,pos)


# degree distribution
plt.hist ([d[1] for d in graph.degree()])
plt.xlabel("Degrees")
plt.ylabel("Number of nodes")
plt.show ()
# Out:
# matplotlib: 3.5.0
# Name:
# Type: Graph
# Number of nodes: 242
# Number of edges: 8317
# Average degree:  68.7355
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2124/2964923238.py in <module>
#      23 print(nx.info(G))
#      24
# ---> 25 draw_graph(G)
#      26 # pos = nx.random_layout(G)
#      27 # nx.draw(G,pos)
#
# ~\AppData\Local\Temp/ipykernel_2124/2964923238.py in draw_graph(G, colors, pos)
#      13 #     nx.draw(G, pos)
#      14     nx.draw_networkx_nodes(G, pos, node_color=colors, cmap=plt.cm.YlOrRd)
# ---> 15     nx.draw_networkx_edges(G, pos)
#      16     nx.draw_networkx_labels(G, pos)
#      17     plt.show()
#
# ...
